# %%
import tensorflow as tf
# TensorFlow에서 사용할 수 있는 GPU 확인
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print(f"사용 가능한 GPU 장치: {gpus}")
else:
    print("사용 가능한 GPU가 없습니다.")

# 간단한 행렬 연산을 통해 GPU 사용 여부 테스트
with tf.device('/GPU:0'):  # GPU:0은 첫 번째 GPU를 의미합니다.
    a = tf.random.normal([10000, 10000])
    b = tf.random.normal([10000, 10000])
    result = tf.matmul(a, b)
    print(result)
print("연산 완료.")
# Out:
# 2024-09-06 10:32:36.117030: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-06 10:32:38.868008: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libdirectml.d6f03b303ac3c4f2eeb8ca631688c9757b361310.so
# 2024-09-06 10:32:38.868115: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libdxcore.so
# 2024-09-06 10:32:38.872056: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libd3d12.so
# 2024-09-06 10:32:39.323374: I tensorflow/c/logging.cc:34] DirectML device enumeration: found 1 compatible adapters.
# 사용 가능한 GPU 장치: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2024-09-06 10:32:39.658372: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-06 10:32:39.660945: I tensorflow/c/logging.cc:34] DirectML: creating device on adapter 0 (AMD Radeon(TM) Graphics)
# 2024-09-06 10:32:39.721669: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-06 10:32:39.721718: W tensorflow/core/common_runtime/pluggable_device/pluggable_device_bfc_allocator.cc:28] Overriding allow_growth setting because force_memory_growth was requested by the device.
# 2024-09-06 10:32:39.721739: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14853 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# tf.Tensor(
# [[  32.09779     72.39235     48.508186  ...  -44.52742     18.36792
#    -16.088472 ]
#  [  -0.9115281  -32.60712     42.946457  ...  -49.792023    31.266762
#   -123.89884  ]
#  [ -60.10315    -62.533028   -35.39275   ... -175.25078   -131.52107
#     18.205479 ]
#  ...
#  [ -82.22572     45.45828   -129.18239   ... -119.56329    -46.194893
#     86.369026 ]
#  [  -6.560537   186.82747     11.013066  ...  -71.08399     31.216307
#    -38.411446 ]
#  [-111.71008    -97.32749     49.9149    ...   66.32707    -30.917269
#      1.5341479]], shape=(10000, 10000), dtype=float32)
# 연산 완료.
