# %%
import time
from datetime import date
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
today = date.today()
print(today, type(today))
today = str(today)
# print(today, type(today))
# Out:
# 2024-09-11 <class 'datetime.date'>

# %%
page = 1
page_size = 100
final_result_df = pd.DataFrame()
while True:
    url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
    payload = dict(method='searchCorpList',pageIndex=page, currentPageSize=page_size,orderMode=3,orderStat='D',searchType=13, fiscalYearEnd='all', location='all')
    r = requests.get(url, params=payload)
    print(r.status_code, end="\r")
    soup = bs(r.text, 'lxml')
    total_items = int(soup.select_one(".info.type-00 > em").text.replace(",", ""))
    total_pages = total_items // page_size + 1
    print(f"{page}/{total_pages} 수집중", end="\r")
    keys = soup.select_one("table.list.type-00.tmt30")['summary'].split(", ")  
    result = {}
    for tr in soup.select('tr'):
        for idx, (key, td) in enumerate(zip(keys, tr.select('td'))):
            if idx == 0:
                kinds = [img['alt'].strip() for img in td.select('img')]   # 1번째 증권 종류, 회사이름
                kind = ", ".join(kinds)
                code = td.select_one('a')['onclick'].split("'")[1]+"0" # 종목코드 추출
                result.setdefault('증권종류', []).append(kind) # 증권종류 저장
                result.setdefault(key, []).append(td.text)   # 회사이름 저장
                result.setdefault('종목코드', []).append(code)
            elif idx == 6:
                home_link = td.select_one('a')['href'] if td.string == None else ""  # 6번째 링크 찾기
                result.setdefault(key, []).append(home_link)
            else:
                result.setdefault(key, []).append(td.text)
    result_df = pd.DataFrame(result)
    final_result_df = pd.concat([final_result_df, result_df])
        
    if page < total_pages:
        page += 1
        time.sleep(5)
    else:
        break

display(final_result_df)
# final_result_df.to_csv(f"상장기업정보{today}_기준.csv", encoding='utf-8', index=False)  # 수집일 기준으로 csv 파일로 저장
# Out:
# 28/28 수집중
#                               증권종류            회사명    종목코드  \
# 0                              코스닥    미래에셋비전스팩7호   482680
# 1                              코스닥        아이비젼웍스   469750
# 2                              코스닥      아이스크림미디어   461300
# 3                      코스닥, 투자경고종목          이엔셀    456070
# 4                              코스닥           M83   476080
# ..                             ...            ...     ...
# 11  유가증권, KTOP30, KOSPI200, KRX300       유한양행      000100
# 12          유가증권, KOSPI200, KRX300      CJ대한통운     000120
# 13                            유가증권            경방   000050
# 14                            유가증권         유수홀딩스   000700
# 15                            유가증권      한진중공업홀딩스   003480
#
#                            업종  \
# 0                  금융 지원 서비스업
# 1               특수 목적용 기계 제조업
# 2              소프트웨어 개발 및 공급업
# 3                 기초 의약물질 제조업
# 4   영화, 비디오물, 방송프로그램 제작 및 배급업
# ..                        ...
# 11                    의약품 제조업
# 12                  도로 화물 운송업
# 13                     종합 소매업
# 14        회사 본부 및 경영 컨설팅 서비스업
# 15          연료용 가스 제조 및 배관공급업
#
#                                                  주요제품         상장일  결산월   대표자명  \
# 0                                              기업인수합병  2024-09-11  12월    송우영
# 1                           이차전지 검사시스템 및 검사시스템 설치셋업용역  2024-09-03  12월    길기재
# 2                                       교육출판, 커머스, 연수  2024-08-30  12월    허주환
# 3          첨단바이오의약품 위탁개발생산(CDMO) 서비스 / 차세대 세포,유전자 치료제  2024-08-23  12월    장종욱
# 4                                                 VFX  2024-08-22  12월  정성진..
# ..                                                ...         ...  ...    ...
# 11  의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01  12월  대표이..
# 12  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월  신영수..
# 13          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월  김준,..
# 14                                               지주사업  1956-03-03  12월    송영규
# 15                                               지주회사  1956-03-03  12월  조남호..
#
#                               홈페이지     지역
# 0                                   서울특별시
# 1   http://www.ivw.co.kr/kor/main/  대전광역시
# 2     http://www.i-screammedia.com    경기도
# 3        http://www.encellinc.com/  서울특별시
# 4                 http://m83.co.kr  서울특별시
# ..                             ...    ...
# 11          http://www.yuhan.co.kr  서울특별시
# 12      http://www.cjlogistics.com  서울특별시
# 13      http://www.kyungbang.co.kr  서울특별시
# 14    http://www.eusu-holdings.com  서울특별시
# 15    http://www.hhic-holdings.com    경기도
#
# [2716 rows x 10 columns]

# %%
final_result_df
# Out:
#                               증권종류            회사명    종목코드  \
# 0                              코스닥    미래에셋비전스팩7호   482680
# 1                              코스닥        아이비젼웍스   469750
# 2                              코스닥      아이스크림미디어   461300
# 3                      코스닥, 투자경고종목          이엔셀    456070
# 4                              코스닥           M83   476080
# ..                             ...            ...     ...
# 11  유가증권, KTOP30, KOSPI200, KRX300       유한양행      000100
# 12          유가증권, KOSPI200, KRX300      CJ대한통운     000120
# 13                            유가증권            경방   000050
# 14                            유가증권         유수홀딩스   000700
# 15                            유가증권      한진중공업홀딩스   003480
#
#                            업종  \
# 0                  금융 지원 서비스업
# 1               특수 목적용 기계 제조업
# 2              소프트웨어 개발 및 공급업
# 3                 기초 의약물질 제조업
# 4   영화, 비디오물, 방송프로그램 제작 및 배급업
# ..                        ...
# 11                    의약품 제조업
# 12                  도로 화물 운송업
# 13                     종합 소매업
# 14        회사 본부 및 경영 컨설팅 서비스업
# 15          연료용 가스 제조 및 배관공급업
#
#                                                  주요제품         상장일  결산월   대표자명  \
# 0                                              기업인수합병  2024-09-11  12월    송우영
# 1                           이차전지 검사시스템 및 검사시스템 설치셋업용역  2024-09-03  12월    길기재
# 2                                       교육출판, 커머스, 연수  2024-08-30  12월    허주환
# 3          첨단바이오의약품 위탁개발생산(CDMO) 서비스 / 차세대 세포,유전자 치료제  2024-08-23  12월    장종욱
# 4                                                 VFX  2024-08-22  12월  정성진..
# ..                                                ...         ...  ...    ...
# 11  의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01  12월  대표이..
# 12  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월  신영수..
# 13          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월  김준,..
# 14                                               지주사업  1956-03-03  12월    송영규
# 15                                               지주회사  1956-03-03  12월  조남호..
#
#                               홈페이지     지역
# 0                                   서울특별시
# 1   http://www.ivw.co.kr/kor/main/  대전광역시
# 2     http://www.i-screammedia.com    경기도
# 3        http://www.encellinc.com/  서울특별시
# 4                 http://m83.co.kr  서울특별시
# ..                             ...    ...
# 11          http://www.yuhan.co.kr  서울특별시
# 12      http://www.cjlogistics.com  서울특별시
# 13      http://www.kyungbang.co.kr  서울특별시
# 14    http://www.eusu-holdings.com  서울특별시
# 15    http://www.hhic-holdings.com    경기도
#
# [2716 rows x 10 columns]

# %%
import os
from sqlalchemy import create_engine, text
import pymysql
pymysql.install_as_MySQLdb()
from dotenv import load_dotenv
load_dotenv(dotenv_path="./05data_scraping/.env_db2")
# Out:
# True

# %%
engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}")
conn = engine.connect()

# %%
conn.execute(text('CREATE DATABASE IF NOT EXISTS korean_stock'))
conn.close()

# %%
today = today.replace("-", "_")
today
# Out:
# '2024_09_11'

# %%
engine = create_engine(f"{os.getenv('db')}+{os.getenv('dbtype')}://{os.getenv('id')}:{os.getenv('pw')}@{os.getenv('host')}/{os.getenv('database')}")
conn = engine.connect()
final_result_df.to_sql(f'company_info', con=conn, if_exists='replace', index=False)
conn.close()

# %%
db = "mysql"
dbtype = "pymysql"
id = "root"
pw = "1234"
host = "127.0.0.1:3306"
database = "korean_stock"

# f-string 없이 직접 문자열 연결
engine = create_engine(db + "+" + dbtype + "://" + id + ":" + pw + "@" + host + "/" + database)
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 10
#       8 # f-string 없이 직접 문자열 연결
#       9 engine = create_engine(db + "+" + dbtype + "://" + id + ":" + pw + "@" + host + "/" + database)
# ---> 10 conn = engine.connect()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:3276, in Engine.connect(self)
#    3253 def connect(self) -> Connection:
#    3254     """Return a new :class:`_engine.Connection` object.
#    3255
#    3256     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3273
#    3274     """
# -> 3276     return self._connection_cls(self)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 if connection is None:
#     145     try:
# --> 146         self._dbapi_connection = engine.raw_connection()
#     147     except dialect.loaded_dbapi.Error as err:
#     148         Connection._handle_dbapi_exception_noconnection(
#     149             err, dialect, engine
#     150         )
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\base.py:3300, in Engine.raw_connection(self)
#    3278 def raw_connection(self) -> PoolProxiedConnection:
#    3279     """Return a "raw" DBAPI connection from the connection pool.
#    3280
#    3281     The returned object is a proxied version of the DBAPI
#    (...)
#    3298
#    3299     """
# -> 3300     return self.pool.connect()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\impl.py:179, in QueuePool._do_get(self)
#     177     return self._create_connection()
#     178 except:
# --> 179     with util.safe_reraise():
#     180         self._dec_overflow()
#     181     raise
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:900, in _ConnectionRecord.__connect(self)
#     898     self.fresh = True
#     899 except BaseException as e:
# --> 900     with util.safe_reraise():
#     901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\pool\base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\create.py:643, in create_engine.<locals>.connect(connection_record)
#     640         if connection is not None:
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\engine\default.py:620, in DefaultDialect.connect(self, *cargs, **cparams)
#     618 def connect(self, *cargs, **cparams):
#     619     # inherits the docstring from interfaces.Dialect.connect
# --> 620     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pymysql\connections.py:358, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, collation, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     356     self._sock = None
#     357 else:
# --> 358     self.connect()
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pymysql\connections.py:664, in Connection.connect(self, sock)
#     661 self._next_seq_id = 0
#     663 self._get_server_information()
# --> 664 self._request_authentication()
#     666 # Send "SET NAMES" query on init for:
#     667 # - Ensure charaset (and collation) is set to the server.
#     668 #   - collation_id in handshake packet may be ignored.
#    (...)
#     677 # - https://github.com/wagtail/wagtail/issues/9477
#     678 # - https://zenn.dev/methane/articles/2023-mysql-collation (Japanese)
#     679 self.set_character_set(self.charset, self.collation)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pymysql\connections.py:976, in Connection._request_authentication(self)
#     974 # https://dev.mysql.com/doc/internals/en/successful-authentication.html
#     975 if self._auth_plugin_name == "caching_sha2_password":
# --> 976     auth_packet = _auth.caching_sha2_password_auth(self, auth_packet)
#     977 elif self._auth_plugin_name == "sha256_password":
#     978     auth_packet = _auth.sha256_password_auth(self, auth_packet)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pymysql\_auth.py:266, in caching_sha2_password_auth(conn, pkt)
#     263     if DEBUG:
#     264         print(conn.server_public_key.decode("ascii"))
# --> 266 data = sha2_rsa_encrypt(conn.password, conn.salt, conn.server_public_key)
#     267 pkt = _roundtrip(conn, data)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pymysql\_auth.py:143, in sha2_rsa_encrypt(password, salt, public_key)
#     138 """Encrypt password with salt and public_key.
#     139
#     140 Used for sha256_password and caching_sha2_password.
#     141 """
#     142 if not _have_cryptography:
# --> 143     raise RuntimeError(
#     144         "'cryptography' package is required for sha256_password or"
#     145         + " caching_sha2_password auth methods"
#     146     )
#     147 message = _xor_password(password + b"\0", salt)
#     148 rsa_key = serialization.load_pem_public_key(public_key, default_backend())
#
# RuntimeError: 'cryptography' package is required for sha256_password or caching_sha2_password auth methods

# %%
conn.execute(text('CREATE DATABASE IF NOT EXISTS korean_stock'))
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 conn.execute(text('CREATE DATABASE IF NOT EXISTS korean_stock'))
#       2 conn.close()
#
# NameError: name 'conn' is not defined

# %%
# !pip install cryptography
# Out:
# Collecting cryptography
#   Downloading cryptography-43.0.1-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\5-25\miniforge3\envs\fintech\lib\site-packages (from cryptography) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\5-25\miniforge3\envs\fintech\lib\site-packages (from cffi>=1.12->cryptography) (2.22)
# Downloading cryptography-43.0.1-cp39-abi3-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.1 MB 660.6 kB/s eta 0:00:05
#    ----------------------- ---------------- 1.8/3.1 MB 23.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 28.1 MB/s eta 0:00:00
# Installing collected packages: cryptography
# Successfully installed cryptography-43.0.1
# Note: you may need to restart the kernel to use updated packages.
