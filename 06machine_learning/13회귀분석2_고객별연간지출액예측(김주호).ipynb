# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./data/ecommerce.csv")
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
data.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
data.columns[3:]
# Out:
# Index(['Avg. Session Length', 'Time on App', 'Time on Website',
#        'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
data.describe().loc['75%', 'Avg. Session Length']
# Out:
# 33.711985023954476

# %%
data.describe().loc['75%', 'Avg. Session Length']

# %%
data.describe().loc['25%', 'Avg. Session Length']
# Out:
# 32.34182200451778

# %%
d = data.describe()
a = [1.5*(d.loc['75%', i] - d.loc['25%', i]) + d.loc['75%', i] for i in data.columns[3:]]
a
# Out:
# [35.767229553109516,
#  14.802394229583687,
#  39.76719469493466,
#  5.920580296370714,
#  705.7271533863172]

# %%
b = [d.loc['25%', i] - 1.5*(d.loc['75%', i] - d.loc['25%', i]) for i in data.columns[3:]]
b
# Out:
# [30.286577475362737,
#  9.33960882513129,
#  34.29849491039147,
#  1.136371357955959,
#  288.6249512402365]

# %%
data[]
# Out:
#                          Email  \
# 154       nathan86@hotmail.com
# 390  michaelcampbell@yahoo.com
#
#                                                Address        Avatar  \
# 154        748 Michael Plaza\nWest Billyside, UT 20799  MidnightBlue
# 390  96480 White Lane Suite 521\nPattersonhaven, OR...          Gray
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 154            36.139662    12.050267        36.959643              3.864861
# 390            35.860237    11.730661        36.882149              3.416210
#
#      Yearly Amount Spent
# 154           595.803819
# 390           546.556667

# %%
data.iloc[154, 3] = 35.767229553109516
data.iloc[154, 3]
# Out:
# 35.767229553109516

# %%
data.iloc[390, 3] = 35.767229553109516
data.iloc[390, 3]
# Out:
# 35.767229553109516

# %%
data[data['Avg. Session Length'] < 30.286577475362737]
# Out:
#                 Email                                            Address  \
# 12  knelson@gmail.com  6705 Miller Orchard Suite 186\nLake Shanestad,...
#
#        Avatar  Avg. Session Length  Time on App  Time on Website  \
# 12  RoyalBlue            29.532429    10.961298        37.420216
#
#     Length of Membership  Yearly Amount Spent
# 12              4.046423           408.640351

# %%
data.iloc[12, 3] = 30.286577475362737
data.iloc[12, 3]
# Out:
# 30.286577475362737

# %%
data[data['Time on App'] > 14.802394229583687]
# Out:
#              Email                                           Address  \
# 65  kyang@diaz.org  223 Love Trail Suite 831\nPort Jeffrey, IN 46849
#
#        Avatar  Avg. Session Length  Time on App  Time on Website  \
# 65  OliveDrab            34.374258    15.126994        37.157624
#
#     Length of Membership  Yearly Amount Spent
# 65              5.377594           765.518462

# %%
data.iloc[65, 4] = 14.802394229583687
data.iloc[65, 4]
# Out:
# 14.802394229583687

# %%
data[data['Time on App'] < 9.33960882513129]
# Out:
#                                 Email  \
# 309                  dblair@gmail.com
# 362                   cruiz@yahoo.com
# 442  martinkristi@sanchez-coleman.com
#
#                                                Address           Avatar  \
# 309     190 Kelley Burg\nWest Juliaport, IA 35826-8163  MediumSlateBlue
# 362  497 Julian Brook Suite 872\nHillberg, FM 87927...      LightSalmon
# 442                   PSC 1893, Box 7023\nAPO AA 73445             Lime
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 309            34.102279     8.508152        35.462400              1.838211
# 362            33.981006     9.316289        36.914952              2.868428
# 442            34.083663     8.668350        35.906756              2.252446
#
#      Yearly Amount Spent
# 309           302.189548
# 362           384.326057
# 442           308.527747

# %%
data.iloc[309, 4], data.iloc[362, 4], data.iloc[442, 4] = 9.33960882513129, 9.33960882513129, 9.33960882513129
data.iloc[309, 4], data.iloc[362, 4], data.iloc[442, 4]
# Out:
# (9.33960882513129, 9.33960882513129, 9.33960882513129)

# %%
data[data['Time on Website'] > 39.76719469493466]
# Out:
#                           Email                                       Address  \
# 69  davisrobert@hicks-smith.com  95967 Pitts Burgs\nWest Sarah, MH 27817-5147
#
#      Avatar  Avg. Session Length  Time on App  Time on Website  \
# 69  SkyBlue              32.1791    11.187539        40.005182
#
#     Length of Membership  Yearly Amount Spent
# 69               3.55265           451.575685

# %%
data.iloc[69, 5] = 39.76719469493466
data.iloc[69, 5]
# Out:
# 39.76719469493466

# %%
data[data['Time on Website'] < 34.29849491039147]
# Out:
#                 Email                     Address Avatar  Avg. Session Length  \
# 157  asilva@yahoo.com  USNV Johnson\nFPO AP 19026  Wheat            34.603311
#
#      Time on App  Time on Website  Length of Membership  Yearly Amount Spent
# 157    12.207298        33.913847              6.922689           744.221867

# %%
data.iloc[157, 5] = 34.29849491039147
data.iloc[157, 5]
# Out:
# 34.29849491039147

# %%
data[data['Length of Membership'] > 5.920580296370714]
# Out:
#                      Email                                            Address  \
# 50     william82@gmail.com         11143 Park Squares\nSamanthatown, UT 97073
# 151       alicia85@lee.com  14220 Carla Flat Suite 521\nLake Matthew, DE 0...
# 153     ebrown@osborne.com  4291 Nichols Fork Apt. 562\nThomaschester, SC ...
# 157       asilva@yahoo.com                         USNV Johnson\nFPO AP 19026
# 396  waltonkaren@gmail.com  355 Villegas Isle Apt. 070\nWest Jenniferview,...
#
#             Avatar  Avg. Session Length  Time on App  Time on Website  \
# 50      SandyBrown            33.256335    13.858062        37.780265
# 151        DimGray            32.887105    12.387184        37.431159
# 153  DarkSlateGray            31.945396    12.965761        36.966389
# 157          Wheat            34.603311    12.207298        34.298495
# 396          Green            35.742670    10.889828        35.565436
#
#      Length of Membership  Yearly Amount Spent
# ...

# %%
data.iloc[50, 6], data.iloc[151, 6], data.iloc[153, 6], data.iloc[157, 6], data.iloc[396, 6] = 5.920580296370714, 5.920580296370714, 5.920580296370714, 5.920580296370714, 5.920580296370714
data.iloc[50, 6], data.iloc[151, 6], data.iloc[153, 6], data.iloc[157, 6], data.iloc[396, 6]
# Out:
# (5.920580296370714,
#  5.920580296370714,
#  5.920580296370714,
#  5.920580296370714,
#  5.920580296370714)

# %%
data[data['Length of Membership'] < 1.136371357955959]
# Out:
#                              Email  \
# 161       stevenking@patterson.com
# 173        fischermonica@gmail.com
# 225  alexandra26@summers-davis.com
# 303       brandon77@richardson.com
# 379               tsmith@yahoo.com
# 434          jordandavid@gmail.com
# 447         sharongraves@yahoo.com
#
#                                                Address      Avatar  \
# 161     94730 Martin Mount\nNew Matthew, VI 08142-6708   LightGray
# 173  9847 Michael Plaza Suite 837\nLake Christopher...        Navy
# 225              Unit 7032 Box 7016\nDPO AE 44749-2992        Navy
# 303   109 Jessica Manor\nNorth Patriciashire, PR 84726  GhostWhite
# 379  92028 Thomas Mountains Suite 044\nNew Matthew,...      Bisque
# 434  61502 Parker Vista Apt. 363\nJonesshire, GU 33532      Violet
# 447  73098 Ronald Port\nCliffordborough, MO 37479-9244       Wheat
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# ...

# %%
data.iloc[161, 6], data.iloc[173, 6], data.iloc[225, 6], data.iloc[303, 6], data.iloc[379, 6], data.iloc[434, 6], data.iloc[447, 6] = 1.136371357955959, 1.136371357955959, 1.136371357955959, 1.136371357955959, 1.136371357955959, 1.136371357955959, 1.136371357955959
data.iloc[161, 6], data.iloc[173, 6], data.iloc[225, 6], data.iloc[303, 6], data.iloc[379, 6], data.iloc[434, 6], data.iloc[447, 6]
# Out:
# (1.136371357955959,
#  1.136371357955959,
#  1.136371357955959,
#  1.136371357955959,
#  1.136371357955959,
#  1.136371357955959,
#  1.136371357955959)

# %%
data[data['Yearly Amount Spent'] > 705.7271533863172]
# Out:
#                                Email  \
# 50               william82@gmail.com
# 65                    kyang@diaz.org
# 157                 asilva@yahoo.com
# 205  jeffrey54@mcdonald-williams.com
# 368               rhonda01@gmail.com
#
#                                               Address      Avatar  \
# 50         11143 Park Squares\nSamanthatown, UT 97073  SandyBrown
# 65   223 Love Trail Suite 831\nPort Jeffrey, IN 46849   OliveDrab
# 157                        USNV Johnson\nFPO AP 19026       Wheat
# 205  297 Francis Valley\nSouth Lindsey, NY 13669-5367   Gainsboro
# 368         939 Watson Run\nStaceyberg, VT 58376-0454      Orchid
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 50             33.256335    13.858062        37.780265              5.920580
# 65             34.374258    14.802394        37.157624              5.377594
# 157            34.603311    12.207298        34.298495              5.920580
# ...

# %%
data.iloc[50, 7], data.iloc[65, 7], data.iloc[157, 7], data.iloc[205, 7], data.iloc[368, 7] = 705.7271533863172, 705.7271533863172, 705.7271533863172, 705.7271533863172, 705.7271533863172
data.iloc[50, 7], data.iloc[65, 7], data.iloc[157, 7], data.iloc[205, 7], data.iloc[368, 7]
# Out:
# (705.7271533863172,
#  705.7271533863172,
#  705.7271533863172,
#  705.7271533863172,
#  705.7271533863172)

# %%
data[data['Yearly Amount Spent'] < 288.6249512402365]
# Out:
#                              Email  \
# 225  alexandra26@summers-davis.com
# 299       morganorozco@hotmail.com
# 303       brandon77@richardson.com
# 415              brian51@cook.info
#
#                                               Address       Avatar  \
# 225             Unit 7032 Box 7016\nDPO AE 44749-2992         Navy
# 299     0001 Mack Mill\nNorth Jennifer, NE 42021-5936    LightPink
# 303  109 Jessica Manor\nNorth Patriciashire, PR 84726   GhostWhite
# 415   0508 Terrance Cliff\nRebekahtown, NC 48724-8308  SaddleBrown
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 225            32.836941    10.256549        36.143908              1.136371
# 299            30.492537    11.562936        35.976565              1.481617
# 303            30.816201    11.851399        36.925043              1.136371
# 415            31.517122    10.745189        38.791235              1.428824
#
#      Yearly Amount Spent
# 225           256.670582
# ...

# %%
data.iloc[225, 7], data.iloc[299, 7], data.iloc[303, 7], data.iloc[415, 7] = 288.6249512402365, 288.6249512402365, 288.6249512402365, 288.6249512402365
data.iloc[225, 7], data.iloc[299, 7], data.iloc[303, 7], data.iloc[415, 7]
# Out:
# (288.6249512402365, 288.6249512402365, 288.6249512402365, 288.6249512402365)

# %%
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...
